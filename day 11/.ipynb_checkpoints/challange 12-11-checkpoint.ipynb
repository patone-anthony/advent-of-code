# %%
import pandas as pd
pd.options.display.max_columns = None

# %%
with open('input 12-11.txt') as f:
#     file = f.read().splitlines() 
    file = f.read().split('\n\n')

# %%
file[0]
# Out:
# 'Monkey 0:\n  Starting items: 79, 98\n  Operation: new = old * 19\n  Test: divisible by 23\n    If true: throw to monkey 2\n    If false: throw to monkey 3'

# %%
# store a list of monkeys
monk_lst = []
for monk in file:
#     print(monk)
    _monk = monk.split('\n')
    monk_lst.append(_monk)
    print(f'\n {_monk}')
# Out:
#  ['Monkey 0:', '  Starting items: 79, 98', '  Operation: new = old * 19', '  Test: divisible by 23', '    If true: throw to monkey 2', '    If false: throw to monkey 3']
#
#  ['Monkey 1:', '  Starting items: 54, 65, 75, 74', '  Operation: new = old + 6', '  Test: divisible by 19', '    If true: throw to monkey 2', '    If false: throw to monkey 0']
#
#  ['Monkey 2:', '  Starting items: 79, 60, 97', '  Operation: new = old * old', '  Test: divisible by 13', '    If true: throw to monkey 1', '    If false: throw to monkey 3']
#
#  ['Monkey 3:', '  Starting items: 74', '  Operation: new = old + 3', '  Test: divisible by 17', '    If true: throw to monkey 0', '    If false: throw to monkey 1']

# %%
class Monkey:
    def __init__(self, name, worry, items, oper, op_num, divis, if_true, if_false):
        self.name = name
        self.worry = worry
        self.items = items
        self.oper = oper
        self.op_num = op_num
        self.divis = divis
        self.if_true = if_true
        self.if_false = if_false

# %%
final = []
for index, monk in enumerate(monk_lst):
#     print(monk)
#     print(index)
    for i in range(len(monk)):
#         print(f'\n i={i}')
        
        # index/name
        if i == 0:
            pass
#             _ind = monk[i].split('Monkey ')[1]
#             index = _ind.split(':')[0]
#             print(index)
        
        #items
        elif i == 1:
#             print(monk[i])
            _items = monk[i].split('Starting items: ')[1]
#             print(f'_itmems = {_items}')
            items = [int(x) for x in _items.split(', ')]
#             print(f'final items= {items}')
            
        # oper:
        elif i == 2:
            #oper (either + or *)
            # locate either operator, store char and position
            # split on position to get number following
            for j in range(len(monk[i])):
                if monk[i][j] == '*' or monk[i][j] == '+':
#                     print(f'char found {monk[i][j]} index={j}')
                    oper = monk[i][j]
                    op_num = monk[i][j+2:]
#                     print(f'op_num {op_num}')
                    break
                    
        # divis
        elif i == 3:
            divis = int(monk[i].split('Test: divisible by ')[1])
#             print(f'divis={divis}')
            
         #if true
        elif i == 4:
            if_true = int(monk[i].split('If true: throw to monkey ')[1])
#             print(f'divis={if_true}')
               
         #if false
        elif i == 5:
            if_false = int(monk[i].split('If false: throw to monkey ')[1])
#             print(f'divis={if_false}')  
        
    temp = Monkey(index, 0, items, oper, op_num, divis, if_true, if_false)
    final.append(temp)

for i in final:
    print(vars(i))
# Out:
# {'name': 0, 'worry': 0, 'items': [79, 98], 'oper': '*', 'op_num': '19', 'divis': 23, 'if_true': 2, 'if_false': 3}
# {'name': 1, 'worry': 0, 'items': [54, 65, 75, 74], 'oper': '+', 'op_num': '6', 'divis': 19, 'if_true': 2, 'if_false': 0}
# {'name': 2, 'worry': 0, 'items': [79, 60, 97], 'oper': '*', 'op_num': 'old', 'divis': 13, 'if_true': 1, 'if_false': 3}
# {'name': 3, 'worry': 0, 'items': [74], 'oper': '+', 'op_num': '3', 'divis': 17, 'if_true': 0, 'if_false': 1}

# %%
# loop through 20 times

# 1. if there are items, iterate through items
# 2. multiply worry level by popped item
# 3. get operator and divid divide that number by 

for i in range(2):
    print(f'\n ######### round={i}')
    for monk in final:
        print('\n',vars(monk))
        while monk.items:
            print(monk.items)
            popped_item = monk.items.pop(0)
            monk.worry += popped_item
            print(f'popped {popped_item}, worry: {monk.worry}')

            # get operator (can be + or *)
            # check operation can be add or multiply
            if monk.oper == '*':
                if monk.op_num == 'old':
                    monk.worry *= monk.worry 
                elif monk.op_num.isdigit():
                    monk.worry *= int(monk.op_num)
                    print(f'monk.worry {monk.worry} * op_num {int(monk.op_num)}')
            elif monk.oper == '+':
                if monk.op_num == 'old':
                    monk.worry += monk.worry          
                elif monk.op_num.isdigit():
                    monk.worry += int(monk.op_num)
                    print(f'monk.op_num is digit {monk.op_num.isdigit()}')

            print(f'monk.worry={monk.worry}')
            monk.worry = int(monk.worry / 3)
            print(f'monk.worry={monk.worry}')
            # divisible
            
            print(f'check if monk.worry={monk.worry} % divis={monk.divis}  equals={monk.worry%divis}')
            if monk.worry % monk.divis == 0:
                print('if true')
                final[monk.if_true].items.append(monk.worry) 
                print(f'{monk.worry} thrown to monkey_{monk.if_true}')
            else:
                print('if false')
                print(vars(final[if_false]))
                final[monk.if_false].items.append(int(monk.worry))  
                print(f'{int(monk.worry)} thrown to monkey_{monk.if_false}')

            monk.worry = 0
            
    for i in final:
        print(vars(i))
# Out:
#  ######### round=0
#
#  {'name': 0, 'worry': 0, 'items': [79, 98], 'oper': '*', 'op_num': '19', 'divis': 23, 'if_true': 2, 'if_false': 3}
# [79, 98]
# popped 79, worry: 79
# monk.worry 1501 * op_num 19
# monk.worry=1501
# monk.worry=500
# check if monk.worry=500 % divis=23  equals=7
# if false
# {'name': 1, 'worry': 0, 'items': [54, 65, 75, 74], 'oper': '+', 'op_num': '6', 'divis': 19, 'if_true': 2, 'if_false': 0}
# 500 thrown to monkey_3
# [98]
# popped 98, worry: 98
# monk.worry 1862 * op_num 19
# monk.worry=1862
# monk.worry=620
# check if monk.worry=620 % divis=23  equals=8
# if false
# {'name': 1, 'worry': 0, 'items': [54, 65, 75, 74], 'oper': '+', 'op_num': '6', 'divis': 19, 'if_true': 2, 'if_false': 0}
# 620 thrown to monkey_3
#
#  {'name': 1, 'worry': 0, 'items': [54, 65, 75, 74], 'oper': '+', 'op_num': '6', 'divis': 19, 'if_true': 2, 'if_false': 0}
# [54, 65, 75, 74]
# popped 54, worry: 54
# monk.op_num is digit True
# monk.worry=60
# monk.worry=20
# check if monk.worry=20 % divis=19  equals=3
# if false
# {'name': 1, 'worry': 20, 'items': [65, 75, 74], 'oper': '+', 'op_num': '6', 'divis': 19, 'if_true': 2, 'if_false': 0}
# 20 thrown to monkey_0
# [65, 75, 74]
# popped 65, worry: 65
# monk.op_num is digit True
# monk.worry=71
# monk.worry=23
# check if monk.worry=23 % divis=19  equals=6
# if false
# {'name': 1, 'worry': 23, 'items': [75, 74], 'oper': '+', 'op_num': '6', 'divis': 19, 'if_true': 2, 'if_false': 0}
# 23 thrown to monkey_0
# [75, 74]
# popped 75, worry: 75
# monk.op_num is digit True
# monk.worry=81
# monk.worry=27
# check if monk.worry=27 % divis=19  equals=10
# if false
# {'name': 1, 'worry': 27, 'items': [74], 'oper': '+', 'op_num': '6', 'divis': 19, 'if_true': 2, 'if_false': 0}
# 27 thrown to monkey_0
# [74]
# popped 74, worry: 74
# monk.op_num is digit True
# monk.worry=80
# monk.worry=26
# check if monk.worry=26 % divis=19  equals=9
# if false
# {'name': 1, 'worry': 26, 'items': [], 'oper': '+', 'op_num': '6', 'divis': 19, 'if_true': 2, 'if_false': 0}
# 26 thrown to monkey_0
#
#  {'name': 2, 'worry': 0, 'items': [79, 60, 97], 'oper': '*', 'op_num': 'old', 'divis': 13, 'if_true': 1, 'if_false': 3}
# [79, 60, 97]
# popped 79, worry: 79
# monk.worry=6241
# monk.worry=2080
# check if monk.worry=2080 % divis=13  equals=6
# if false
# {'name': 1, 'worry': 0, 'items': [], 'oper': '+', 'op_num': '6', 'divis': 19, 'if_true': 2, 'if_false': 0}
# 2080 thrown to monkey_3
# [60, 97]
# popped 60, worry: 60
# monk.worry=3600
# monk.worry=1200
# check if monk.worry=1200 % divis=13  equals=10
# if false
# {'name': 1, 'worry': 0, 'items': [], 'oper': '+', 'op_num': '6', 'divis': 19, 'if_true': 2, 'if_false': 0}
# 1200 thrown to monkey_3
# [97]
# popped 97, worry: 97
# monk.worry=9409
# monk.worry=3136
# check if monk.worry=3136 % divis=13  equals=8
# if false
# {'name': 1, 'worry': 0, 'items': [], 'oper': '+', 'op_num': '6', 'divis': 19, 'if_true': 2, 'if_false': 0}
# 3136 thrown to monkey_3
#
#  {'name': 3, 'worry': 0, 'items': [74, 500, 620, 2080, 1200, 3136], 'oper': '+', 'op_num': '3', 'divis': 17, 'if_true': 0, 'if_false': 1}
# [74, 500, 620, 2080, 1200, 3136]
# popped 74, worry: 74
# monk.op_num is digit True
# monk.worry=77
# monk.worry=25
# check if monk.worry=25 % divis=17  equals=8
# if false
# {'name': 1, 'worry': 0, 'items': [], 'oper': '+', 'op_num': '6', 'divis': 19, 'if_true': 2, 'if_false': 0}
# 25 thrown to monkey_1
# [500, 620, 2080, 1200, 3136]
# popped 500, worry: 500
# monk.op_num is digit True
# monk.worry=503
# monk.worry=167
# check if monk.worry=167 % divis=17  equals=14
# if false
# {'name': 1, 'worry': 0, 'items': [25], 'oper': '+', 'op_num': '6', 'divis': 19, 'if_true': 2, 'if_false': 0}
# 167 thrown to monkey_1
# [620, 2080, 1200, 3136]
# popped 620, worry: 620
# monk.op_num is digit True
# monk.worry=623
# monk.worry=207
# check if monk.worry=207 % divis=17  equals=3
# if false
# {'name': 1, 'worry': 0, 'items': [25, 167], 'oper': '+', 'op_num': '6', 'divis': 19, 'if_true': 2, 'if_false': 0}
# 207 thrown to monkey_1
# [2080, 1200, 3136]
# popped 2080, worry: 2080
# monk.op_num is digit True
# monk.worry=2083
# monk.worry=694
# check if monk.worry=694 % divis=17  equals=14
# if false
# {'name': 1, 'worry': 0, 'items': [25, 167, 207], 'oper': '+', 'op_num': '6', 'divis': 19, 'if_true': 2, 'if_false': 0}
# 694 thrown to monkey_1
# [1200, 3136]
# popped 1200, worry: 1200
# monk.op_num is digit True
# monk.worry=1203
# monk.worry=401
# check if monk.worry=401 % divis=17  equals=10
# if false
# {'name': 1, 'worry': 0, 'items': [25, 167, 207, 694], 'oper': '+', 'op_num': '6', 'divis': 19, 'if_true': 2, 'if_false': 0}
# 401 thrown to monkey_1
# [3136]
# popped 3136, worry: 3136
# monk.op_num is digit True
# monk.worry=3139
# monk.worry=1046
# check if monk.worry=1046 % divis=17  equals=9
# if false
# {'name': 1, 'worry': 0, 'items': [25, 167, 207, 694, 401], 'oper': '+', 'op_num': '6', 'divis': 19, 'if_true': 2, 'if_false': 0}
# 1046 thrown to monkey_1
# {'name': 0, 'worry': 0, 'items': [20, 23, 27, 26], 'oper': '*', 'op_num': '19', 'divis': 23, 'if_true': 2, 'if_false': 3}
# {'name': 1, 'worry': 0, 'items': [25, 167, 207, 694, 401, 1046], 'oper': '+', 'op_num': '6', 'divis': 19, 'if_true': 2, 'if_false': 0}
# {'name': 2, 'worry': 0, 'items': [], 'oper': '*', 'op_num': 'old', 'divis': 13, 'if_true': 1, 'if_false': 3}
# {'name': 3, 'worry': 0, 'items': [], 'oper': '+', 'op_num': '3', 'divis': 17, 'if_true': 0, 'if_false': 1}
#
#  ######### round=1
#
#  {'name': 0, 'worry': 0, 'items': [20, 23, 27, 26], 'oper': '*', 'op_num': '19', 'divis': 23, 'if_true': 2, 'if_false': 3}
# [20, 23, 27, 26]
# popped 20, worry: 20
# monk.worry 380 * op_num 19
# monk.worry=380
# monk.worry=126
# check if monk.worry=126 % divis=23  equals=7
# if false
# {'name': 1, 'worry': 0, 'items': [25, 167, 207, 694, 401, 1046], 'oper': '+', 'op_num': '6', 'divis': 19, 'if_true': 2, 'if_false': 0}
# 126 thrown to monkey_3
# [23, 27, 26]
# popped 23, worry: 23
# monk.worry 437 * op_num 19
# monk.worry=437
# monk.worry=145
# check if monk.worry=145 % divis=23  equals=9
# if false
# {'name': 1, 'worry': 0, 'items': [25, 167, 207, 694, 401, 1046], 'oper': '+', 'op_num': '6', 'divis': 19, 'if_true': 2, 'if_false': 0}
# 145 thrown to monkey_3
# [27, 26]
# popped 27, worry: 27
# monk.worry 513 * op_num 19
# monk.worry=513
# monk.worry=171
# check if monk.worry=171 % divis=23  equals=1
# if false
# {'name': 1, 'worry': 0, 'items': [25, 167, 207, 694, 401, 1046], 'oper': '+', 'op_num': '6', 'divis': 19, 'if_true': 2, 'if_false': 0}
# 171 thrown to monkey_3
# [26]
# popped 26, worry: 26
# monk.worry 494 * op_num 19
# monk.worry=494
# monk.worry=164
# check if monk.worry=164 % divis=23  equals=11
# if false
# {'name': 1, 'worry': 0, 'items': [25, 167, 207, 694, 401, 1046], 'oper': '+', 'op_num': '6', 'divis': 19, 'if_true': 2, 'if_false': 0}
# 164 thrown to monkey_3
#
#  {'name': 1, 'worry': 0, 'items': [25, 167, 207, 694, 401, 1046], 'oper': '+', 'op_num': '6', 'divis': 19, 'if_true': 2, 'if_false': 0}
# [25, 167, 207, 694, 401, 1046]
# popped 25, worry: 25
# monk.op_num is digit True
# monk.worry=31
# monk.worry=10
# check if monk.worry=10 % divis=19  equals=10
# if false
# {'name': 1, 'worry': 10, 'items': [167, 207, 694, 401, 1046], 'oper': '+', 'op_num': '6', 'divis': 19, 'if_true': 2, 'if_false': 0}
# 10 thrown to monkey_0
# [167, 207, 694, 401, 1046]
# popped 167, worry: 167
# monk.op_num is digit True
# monk.worry=173
# monk.worry=57
# check if monk.worry=57 % divis=19  equals=6
# if false
# {'name': 1, 'worry': 57, 'items': [207, 694, 401, 1046], 'oper': '+', 'op_num': '6', 'divis': 19, 'if_true': 2, 'if_false': 0}
# 57 thrown to monkey_0
# [207, 694, 401, 1046]
# popped 207, worry: 207
# monk.op_num is digit True
# monk.worry=213
# monk.worry=71
# check if monk.worry=71 % divis=19  equals=3
# if false
# {'name': 1, 'worry': 71, 'items': [694, 401, 1046], 'oper': '+', 'op_num': '6', 'divis': 19, 'if_true': 2, 'if_false': 0}
# 71 thrown to monkey_0
# [694, 401, 1046]
# popped 694, worry: 694
# monk.op_num is digit True
# monk.worry=700
# monk.worry=233
# check if monk.worry=233 % divis=19  equals=12
# if false
# {'name': 1, 'worry': 233, 'items': [401, 1046], 'oper': '+', 'op_num': '6', 'divis': 19, 'if_true': 2, 'if_false': 0}
# 233 thrown to monkey_0
# [401, 1046]
# popped 401, worry: 401
# monk.op_num is digit True
# monk.worry=407
# monk.worry=135
# check if monk.worry=135 % divis=19  equals=16
# if false
# {'name': 1, 'worry': 135, 'items': [1046], 'oper': '+', 'op_num': '6', 'divis': 19, 'if_true': 2, 'if_false': 0}
# 135 thrown to monkey_0
# [1046]
# popped 1046, worry: 1046
# monk.op_num is digit True
# monk.worry=1052
# monk.worry=350
# check if monk.worry=350 % divis=19  equals=10
# if false
# {'name': 1, 'worry': 350, 'items': [], 'oper': '+', 'op_num': '6', 'divis': 19, 'if_true': 2, 'if_false': 0}
# 350 thrown to monkey_0
#
#  {'name': 2, 'worry': 0, 'items': [], 'oper': '*', 'op_num': 'old', 'divis': 13, 'if_true': 1, 'if_false': 3}
#
#  {'name': 3, 'worry': 0, 'items': [126, 145, 171, 164], 'oper': '+', 'op_num': '3', 'divis': 17, 'if_true': 0, 'if_false': 1}
# [126, 145, 171, 164]
# popped 126, worry: 126
# monk.op_num is digit True
# monk.worry=129
# monk.worry=43
# check if monk.worry=43 % divis=17  equals=9
# if false
# {'name': 1, 'worry': 0, 'items': [], 'oper': '+', 'op_num': '6', 'divis': 19, 'if_true': 2, 'if_false': 0}
# 43 thrown to monkey_1
# [145, 171, 164]
# popped 145, worry: 145
# monk.op_num is digit True
# monk.worry=148
# monk.worry=49
# check if monk.worry=49 % divis=17  equals=15
# if false
# {'name': 1, 'worry': 0, 'items': [43], 'oper': '+', 'op_num': '6', 'divis': 19, 'if_true': 2, 'if_false': 0}
# 49 thrown to monkey_1
# [171, 164]
# popped 171, worry: 171
# monk.op_num is digit True
# monk.worry=174
# monk.worry=58
# check if monk.worry=58 % divis=17  equals=7
# if false
# {'name': 1, 'worry': 0, 'items': [43, 49], 'oper': '+', 'op_num': '6', 'divis': 19, 'if_true': 2, 'if_false': 0}
# 58 thrown to monkey_1
# [164]
# popped 164, worry: 164
# monk.op_num is digit True
# monk.worry=167
# monk.worry=55
# check if monk.worry=55 % divis=17  equals=4
# if false
# {'name': 1, 'worry': 0, 'items': [43, 49, 58], 'oper': '+', 'op_num': '6', 'divis': 19, 'if_true': 2, 'if_false': 0}
# 55 thrown to monkey_1
# {'name': 0, 'worry': 0, 'items': [10, 57, 71, 233, 135, 350], 'oper': '*', 'op_num': '19', 'divis': 23, 'if_true': 2, 'if_false': 3}
# {'name': 1, 'worry': 0, 'items': [43, 49, 58, 55], 'oper': '+', 'op_num': '6', 'divis': 19, 'if_true': 2, 'if_false': 0}
# {'name': 2, 'worry': 0, 'items': [], 'oper': '*', 'op_num': 'old', 'divis': 13, 'if_true': 1, 'if_false': 3}
# {'name': 3, 'worry': 0, 'items': [], 'oper': '+', 'op_num': '3', 'divis': 17, 'if_true': 0, 'if_false': 1}

# %%
final[2].items
# Out:
# [79, 60, 97]

# %%
79*79
# Out:
# 6241

# %%
2080%18
# Out:
# 9
